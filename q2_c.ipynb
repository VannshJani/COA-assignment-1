# %%
import matplotlib.pyplot as plt

# %%
N = [64,128,256,512,1024]
part_a_cpu_time_int_cpp = [0.27,0.32,0.38,1.06,7.21]
part_a_system_cpu_time_int_cpp = [0.04,0.04,0.05,0.05,0.07]

part_a_cpu_time_double_cpp = [0.27,0.29,0.39,1.05,6.85]
part_a_system_cpu_time_double_cpp = [0.04,0.04,0.04,0.04,0.06]


part_a_cpu_time_int_python = [0.11,0.45,3.15,25.53,209.16]
part_a_system_cpu_time_int_python = [0.01,0.01,0.01,0.02,0.11]

part_a_cpu_time_double_python = [0.11,0.41,2.86,23.77,194.63]
part_a_system_cpu_time_double_python = [0.01,0.01,0.01,0.03,0.11]

# plt.plot(N, part_a_cpu_time_int_cpp, label='C++ CPU time (int)')
# plt.plot(N, part_a_cpu_time_double_cpp, label='C++ CPU time (double)')
# plt.plot(N, part_a_cpu_time_int_python, label='Python CPU time (int)')
# plt.plot(N, part_a_cpu_time_double_python, label='Python CPU time (double)')
# plt.plot(N, part_a_system_cpu_time_int_cpp, label='C++ system CPU time (int)')
# plt.plot(N, part_a_system_cpu_time_double_cpp, label='C++ system CPU time (double)')
plt.plot(N, part_a_system_cpu_time_int_python, label='Python system CPU time (int)')
plt.plot(N, part_a_system_cpu_time_double_python, label='Python system CPU time (double)')
plt.xlabel('N')
plt.xticks([64,128,256,512,1024])
plt.ylabel('CPU time (s)')
plt.title('CPU time vs N')
plt.legend()
plt.show()

# %%
part_b_python_int = [0.0141,0.1006,0.7891,6.8303,59.2898]
part_b_python_double = [0.0106,0.0779,0.6080,5.7154,53.4865]

part_b_cpp_int = [0.0030,0.0192,0.1011,0.6917,6.7847]
part_b_cpp_double = [0.0029,0.0170,0.0923,0.6482,6.8703]

plt.plot(N, part_b_python_int, label='Python exec time (int)')
plt.plot(N, part_b_python_double, label='Python exec time (double)')
# plt.plot(N, part_b_cpp_int, label='C++ exec time (int)')
# plt.plot(N, part_b_cpp_double, label='C++ exec time (double)')
plt.xlabel('N')
plt.xticks([64,128,256,512,1024])
plt.ylabel('Execution time (s)')
plt.title('Execution time vs N')
plt.legend()
plt.show()
